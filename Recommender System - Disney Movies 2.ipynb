# %%
import numpy as np
import pandas as pd

# %%
movies_data = pd.read_csv("C:\\Users\\Aisling\\Documents\\Python Exercises\\walt_disney_movies_1990_present.csv")
movies_data.head(10)
# Out:
#                          title  \
# 0      The Rescuers Down Under
# 1                   White Fang
# 2                  Shipwrecked
# 3  Wild Hearts Can't Be Broken
# 4                The Rocketeer
# 5         Beauty and the Beast
# 6                      Newsies
# 7     Honey, I Blew Up the Kid
# 8             The Mighty Ducks
# 9                      Aladdin
#
#                                   Production company  \
# 0  ['Walt Disney Pictures', 'Walt Disney Feature ...
# 1  ['Walt Disney Pictures', 'Silver Screen Partne...
# 2  ['Walt Disney Pictures', 'AB Svensk Filmindust...
# 3                               Walt Disney Pictures
# 4                                                NaN
# 5                                                NaN
# 6                               Walt Disney Pictures
# 7  ['Walt Disney Pictures', 'Touchwood Pacific Pa...
# 8  ['Walt Disney Pictures', 'Avnetâ€“ Kerner Prod...
# 9                                                NaN
#
# ...

# %%
movies_data.groupby('title')['imdb'].mean().head(10)
# Out:
# title
# 101 Dalmatians                  5.7
# 102 Dalmatians                  4.9
# A Bug's Life                    7.2
# A Christmas Carol               6.8
# A Far Off Place                 6.6
# A Goofy Movie                   6.9
# A Kid in King Arthur's Court    4.7
# A Wrinkle in Time               4.2
# ABCD 2                          NaN
# African Cats                    7.6
# Name: imdb, dtype: float64

# %%
movies_data.groupby('title')['imdb'].mean().head(20)
# Out:
# title
# 101 Dalmatians                                                 5.7
# 102 Dalmatians                                                 4.9
# A Bug's Life                                                   7.2
# A Christmas Carol                                              6.8
# A Far Off Place                                                6.6
# A Goofy Movie                                                  6.9
# A Kid in King Arthur's Court                                   4.7
# A Wrinkle in Time                                              4.2
# ABCD 2                                                         NaN
# African Cats                                                   7.6
# Air Bud                                                        5.2
# Aladdin                                                        8.0
# Alexander and the Terrible, Horrible, No Good, Very Bad Day    6.2
# Alice Through the Looking Glass                                6.2
# ...

# %%
movies_data.groupby('title')['imdb'].mean().sort_values(ascending=False).head()
# Out:
# title
# Spirited Away    8.6
# Hamilton         8.6
# The Lion King    8.5
# Dangal           8.4
# WALL-E           8.4
# Name: imdb, dtype: float64

# %%
imdbrating_mean_count = pd.DataFrame(movies_data.groupby('title')['imdb'].mean())

# %%
imdbrating_mean_count['rating_counts'] = pd.DataFrame(movies_data.groupby('title')['imdb'].mean())

# %%
imdbrating_mean_count.head(5)
# Out:
#                    imdb  rating_counts
# title
# 101 Dalmatians      5.7            5.7
# 102 Dalmatians      4.9            4.9
# A Bug's Life        7.2            7.2
# A Christmas Carol   6.8            6.8
# A Far Off Place     6.6            6.6

# %%
import matplotlib as mp
import seaborn as sb
