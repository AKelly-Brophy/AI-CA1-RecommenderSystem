# %%
import numpy as np
import pandas as pd

# %%
movies_data = pd.read_csv("C:\\Users\\Aisling\\Documents\\Python Exercises\\walt_disney_movies.csv")
movies_data.head(10)
# Out:
#    Unnamed: 0                            title       Production company  \
# 0           0          Academy Award Review of  Walt Disney Productions
# 1           1  Snow White and the Seven Dwarfs  Walt Disney Productions
# 2           2                        Pinocchio  Walt Disney Productions
# 3           3                         Fantasia  Walt Disney Productions
# 4           4             The Reluctant Dragon  Walt Disney Productions
# 5           5                            Dumbo  Walt Disney Productions
# 6           6                            Bambi  Walt Disney Productions
# 7           7                   Saludos Amigos  Walt Disney Productions
# 8           8        Victory Through Air Power  Walt Disney Productions
# 9           9             The Three Caballeros  Walt Disney Productions
#
#          Country                              Language  Running time  \
# 0  United States                               English          41.0
# ...

# %%
movies_data.groupby('title')['imdb'].mean().head(10)
# Out:
# title
# 101 Dalmatians                  5.7
# 102 Dalmatians                  4.9
# 20,000 Leagues Under the Sea    7.2
# A Bug's Life                    7.2
# A Christmas Carol               6.8
# A Far Off Place                 6.6
# A Goofy Movie                   6.9
# A Kid in King Arthur's Court    4.7
# A Tale of Two Critters          7.1
# A Tiger Walks                   6.5
# Name: imdb, dtype: float64

# %%
movies_data.groupby('title')['imdb'].mean().head(20)
# Out:
# title
# 101 Dalmatians                                                 5.7
# 102 Dalmatians                                                 4.9
# 20,000 Leagues Under the Sea                                   7.2
# A Bug's Life                                                   7.2
# A Christmas Carol                                              6.8
# A Far Off Place                                                6.6
# A Goofy Movie                                                  6.9
# A Kid in King Arthur's Court                                   4.7
# A Tale of Two Critters                                         7.1
# A Tiger Walks                                                  6.5
# A Wrinkle in Time                                              4.2
# ABCD 2                                                         NaN
# Academy Award Review of                                        7.2
# African Cats                                                   7.6
# ...

# %%
movies_data.groupby('title')['imdb'].mean().sort_values(ascending=False).head()
# Out:
# title
# Hamilton         8.6
# Spirited Away    8.6
# The Lion King    8.5
# Coco             8.4
# Dangal           8.4
# Name: imdb, dtype: float64

# %%
imdbrating_mean_count = pd.DataFrame(movies_data.groupby('title')['imdb'].mean())

# %%
imdbrating_mean_count['rating_counts'] = pd.DataFrame(movies_data.groupby('title')['imdb'].mean())

# %%
imdbrating_mean_count.head(5)
# Out:
#                               imdb  rating_counts
# title
# 101 Dalmatians                 5.7            5.7
# 102 Dalmatians                 4.9            4.9
# 20,000 Leagues Under the Sea   7.2            7.2
# A Bug's Life                   7.2            7.2
# A Christmas Carol              6.8            6.8

# %%
import matplotlib as mp
import seaborn as sb
